# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 cd
#
# NameError: name 'cd' is not defined

# %%
#current directory
cd
# Out:
# C:\Users\CVR

# %%
hd=pd.read_csv("store_sales.csv")
hd.head()#first 5 rows
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13

# %%
hd.tail()#last 5 rows
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 95   23   22
# 96   12    9
# 97   17   22
# 98   19   10
# 99    5    9

# %%
hd.info() #information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   store_id  100 non-null    object
#  1   city      100 non-null    object
#  2   Jan       100 non-null    int64
#  3   Feb       100 non-null    int64
#  4   Mar       100 non-null    int64
#  5   Apr       100 non-null    int64
#  6   May       100 non-null    int64
#  7   Jun       100 non-null    int64
#  8   July      100 non-null    int64
#  9   Aug       100 non-null    int64
#  10  Sep       100 non-null    int64
#  11  Oct       100 non-null    int64
#  12  Nov       100 non-null    int64
#  13  Dec       100 non-null    int64
# dtypes: int64(12), object(2)
# memory usage: 11.1+ KB

# %%
hd.shape #no.of rows & columns
# Out:
# (100, 14)

# %%
hd.columns #columns in dataset
# Out:
# Index(['store_id', 'city', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'July',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
hd.isnull() #checking null values in dataset
# Out:
#     store_id   city    Jan    Feb    Mar    Apr    May    Jun   July    Aug  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95     False  False  False  False  False  False  False  False  False  False
# 96     False  False  False  False  False  False  False  False  False  False
# 97     False  False  False  False  False  False  False  False  False  False
# 98     False  False  False  False  False  False  False  False  False  False
# 99     False  False  False  False  False  False  False  False  False  False
#
#       Sep    Oct    Nov    Dec
# ...

# %%
hd.isnull().sum()
# Out:
# store_id    0
# city        0
# Jan         0
# Feb         0
# Mar         0
# Apr         0
# May         0
# Jun         0
# July        0
# Aug         0
# Sep         0
# Oct         0
# Nov         0
# Dec         0
# dtype: int64

# %%
#accessing particular column
hd['city']
# Out:
# 0          Texas
# 1     California
# 2     California
# 3          Texas
# 4          Texas
#          ...
# 95         Texas
# 96    California
# 97         Texas
# 98       Arizona
# 99    California
# Name: city, Length: 100, dtype: object

# %%
#unique values in particular column
hd['city'].unique()
# Out:
# array(['Texas', 'California', 'Arizona'], dtype=object)

# %%
#access specific rows and columns
hd.iloc[1:20,1:5]
# Out:
#           city  Jan  Feb  Mar
# 1   California   12   19   15
# 2   California   16   16   14
# 3        Texas    8   18   13
# 4        Texas   19    5   24
# 5   California   14   21   18
# 6      Arizona   11   22    5
# 7   California   15    8    5
# 8        Texas   15    7    6
# 9   California   14   23   20
# 10     Arizona   15   24    8
# 11  California    6   18   21
# 12     Arizona    7   12   18
# 13       Texas   21    7   22
# 14     Arizona   12    6   14
# 15  California   18    9    8
# 16  California   13    8    7
# 17     Arizona   19   21   22
# 18  California    7    6   17
# 19  California   11   21   20

# %%
#checking duplictaes
hd.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
#dropping duplicates
hd.drop_duplicates()
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %%
#count,mean,std,min,max,25%,50%,75%
hd.describe()
# Out:
#               Jan         Feb         Mar         Apr         May         Jun  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    14.460000   15.090000   14.560000   14.570000   13.560000   13.800000
# std      5.712683    6.055459    5.782803    4.965039    5.883241    5.962848
# min      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
# 25%     10.000000    9.000000    9.750000   11.000000    8.000000    9.000000
# 50%     15.000000   16.000000   15.000000   14.500000   13.000000   13.500000
# 75%     19.000000   21.000000   19.250000   19.000000   19.000000   19.000000
# max     24.000000   24.000000   24.000000   24.000000   24.000000   24.000000
#
#              July         Aug         Sep        Oct         Nov         Dec
# count  100.000000  100.000000  100.000000  100.00000  100.000000  100.000000
# mean    14.380000   15.810000   14.910000   14.10000   15.310000   13.570000
# ...

# %%
#rename the column
hd.rename(columns={'Jan':'January'})
# Out:
#    store_id        city  January  Feb  Mar  Apr  May  Jun  July  Aug  Sep  \
# 0       S_1       Texas        8   20   13   21   17   20    24   17   16
# 1       S_2  California       12   19   15   15   11   19     7   15   10
# 2       S_3  California       16   16   14   19   23    6    13   13   15
# 3       S_4       Texas        8   18   13   10   14   14     6    8    8
# 4       S_5       Texas       19    5   24    9    5   24    10    5   24
# ..      ...         ...      ...  ...  ...  ...  ...  ...   ...  ...  ...
# 95     S_96       Texas        7   10   20   20   10   15    15   21   15
# 96     S_97  California       13    6    7   15   22   10    21   23   10
# 97     S_98       Texas       16    9    6   14   20   13    11   10    8
# 98     S_99     Arizona       18   16    9    5   12   22    11   13   21
# 99    S_100  California        5   23   17   24   15   21    19   10   12
#
#     Oct  Nov  Dec
# 0     9    7    6
# 1    11   21   19
# 2    14   24    8
# ...

# %%
hd['Mar'].mean()
# Out:
# 14.56

# %%
hd['Apr'].median()
# Out:
# 14.5

# %%
hd['May'].mode()
# Out:
# 0     5
# 1    12
# 2    15
# Name: May, dtype: int64

# %%
hd['Jun'].std()
# Out:
# 5.962847939999438

# %%
#hd.corr()
# Select only numeric columns for correlation calculation
numeric_df = hd.select_dtypes(include='number')
numeric_df.corr()
# Out:
#            Jan       Feb       Mar       Apr       May       Jun      July  \
# Jan   1.000000 -0.086764 -0.086458 -0.264323  0.013897 -0.043234 -0.097670
# Feb  -0.086764  1.000000 -0.013281  0.141734  0.212354 -0.076706  0.015457
# Mar  -0.086458 -0.013281  1.000000  0.026765 -0.203780  0.119284 -0.142865
# Apr  -0.264323  0.141734  0.026765  1.000000 -0.052880  0.007643  0.225991
# May   0.013897  0.212354 -0.203780 -0.052880  1.000000 -0.151396  0.128224
# Jun  -0.043234 -0.076706  0.119284  0.007643 -0.151396  1.000000 -0.027815
# July -0.097670  0.015457 -0.142865  0.225991  0.128224 -0.027815  1.000000
# Aug   0.130115  0.002633 -0.025370  0.048552 -0.081029 -0.115862  0.185879
# Sep  -0.064201  0.036559 -0.017507  0.029311 -0.218986 -0.051550 -0.012906
# Oct   0.041654  0.070443 -0.042992  0.046506 -0.020925 -0.065165  0.076971
# Nov  -0.077787  0.028451  0.073432  0.004512 -0.043141  0.041475  0.043872
# ...

# %%
hd.isnull().sum()
# Out:
# store_id    0
# city        0
# Jan         0
# Feb         0
# Mar         0
# Apr         0
# May         0
# Jun         0
# July        0
# Aug         0
# Sep         0
# Oct         0
# Nov         0
# Dec         0
# dtype: int64

# %%
hd.fillna(0, inplace=True)
print(hd.isna().sum())
# Out:
# store_id    0
# city        0
# Jan         0
# Feb         0
# Mar         0
# Apr         0
# May         0
# Jun         0
# July        0
# Aug         0
# Sep         0
# Oct         0
# Nov         0
# Dec         0
# dtype: int64

# %%
hd.dtypes
# Out:
# store_id    object
# city        object
# Jan          int64
# Feb          int64
# Mar          int64
# Apr          int64
# May          int64
# Jun          int64
# July         int64
# Aug          int64
# Sep          int64
# Oct          int64
# Nov          int64
# Dec          int64
# dtype: object

# %%
hd.to_numpy
# Out:
# <bound method DataFrame.to_numpy of    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# ...

# %%
#Transposing the data
hd.T
# Out:
#              0           1           2      3      4           5        6   \
# store_id    S_1         S_2         S_3    S_4    S_5         S_6      S_7
# city      Texas  California  California  Texas  Texas  California  Arizona
# Jan           8          12          16      8     19          14       11
# Feb          20          19          16     18      5          21       22
# Mar          13          15          14     13     24          18        5
# Apr          21          15          19     10      9          20       14
# May          17          11          23     14      5          21       16
# Jun          20          19           6     14     24           5       24
# July         24           7          13      6     10          18        8
# Aug          17          15          13      8      5          24       15
# Sep          16          10          15      8     24           7       18
# ...
